# %% [markdown]
# <a href="https://colab.research.google.com/github/Monalika-P/Object-Detection-/blob/main/Yolo-v5/Yolo_v5_Implimenatation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Author - Monalika P

# %% [markdown]
# ## YOLOv5
#
# YOLO v5 is a single-stage object detector, it has three important parts like any other single-stage object detector. Model Backbone is mainly used to extract important features from the given input image.

# %% [markdown]
# ## Clone the YOLOv5 repository

# %%
# !git clone https://github.com/ultralytics/yolov5.git

# %% [markdown]
# ## Change the directory to yolov5

# %%
# %cd yolov5/
# Out:
# /content/yolov5

# %% [markdown]
# ## Installing the dependencies

# %%
# !pip install -U -r requirements.txt
# Out:
# Requirement already up-to-date: Cython in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 4)) (0.29.21)
# Requirement already up-to-date: matplotlib>=3.2.2 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 5)) (3.3.2)
# Requirement already up-to-date: numpy>=1.18.5 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 6)) (1.19.2)
# Requirement already up-to-date: opencv-python>=4.1.2 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 7)) (4.4.0.44)
# Requirement already up-to-date: pillow in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 8)) (8.0.0)
# Requirement already up-to-date: PyYAML>=5.3 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 9)) (5.3.1)
# Requirement already up-to-date: scipy>=1.4.1 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 10)) (1.5.3)
# ...

# %%
# !python detect.py --source ./inference/images/bus.jpg --weights yolov5s.pt --conf 0.4
# Out:
# Namespace(agnostic_nms=False, augment=False, classes=None, conf_thres=0.4, device='', img_size=640, iou_thres=0.45, output='inference/output', save_txt=False, source='./inference/images/bus.jpg', update=False, view_img=False, weights=['yolov5s.pt'])
# Using CPU
#
# Fusing layers...
# Model Summary: 140 layers, 7.45958e+06 parameters, 0 gradients
# image 1/1 /content/yolov5/inference/images/bus.jpg: 640x512 4 persons, 1 buss, Done. (0.393s)
# Results saved to inference/output
# Done. (0.432s)

# %% [markdown]
# ## Displaying the image

# %%
import cv2
import matplotlib.pyplot as plt
# %matplotlib inline

image = cv2.imread("/content/yolov5/inference/output/bus.jpg")
height, width = image.shape[:2]
resized_image = cv2.resize(image,(3*width, 3*height), interpolation = cv2.INTER_CUBIC)

fig = plt.gcf()
fig.set_size_inches(18, 10)
plt.axis("off")
plt.imshow(cv2.cvtColor(resized_image, cv2.COLOR_BGR2RGB))
plt.show()
